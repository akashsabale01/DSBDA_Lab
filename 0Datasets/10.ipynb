# %% [markdown]
# # Assignment-10
# ## Data Visualization III
#
#
# #### -Shantanu Jain- 31369- N3

# %% [markdown]
# IRIS dataset contains a set of 150 records under 5 attributes - Petal Length, Petal Width, Sepal Length, Sepal width and Class(Species).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns,set()
# Out:
# (<module 'seaborn' from '/home/pict/.local/lib/python3.8/site-packages/seaborn/__init__.py'>,
#  set())

# %%
na = ['na','NA', 'N/A', 'n/a','--']
df=pd.read_csv('IRIS.csv', na_values = na)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df["species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sns.set_style("whitegrid");

sns.FacetGrid(df, hue="species", size=4) \
   .map(plt.scatter, "sepal_length", "sepal_width") \
   .add_legend();
plt.show();
# Out:
# /home/pict/.local/lib/python3.8/site-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style("whitegrid");

sns.FacetGrid(df, hue="species", size=4) \
   .map(plt.scatter, "petal_length", "petal_width") \
   .add_legend();
plt.show();
# Out:
# /home/pict/.local/lib/python3.8/site-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
iris_setosa = df.loc[df["species"] == "Iris-setosa"];
iris_virginica = df.loc[df["species"] == "Iris-virginica"];
iris_versicolor = df.loc[df["species"] == "Iris-versicolor"];


plt.plot(iris_setosa["petal_length"], np.zeros_like(iris_setosa['petal_length']), '*')
plt.plot(iris_versicolor["petal_length"], np.zeros_like(iris_versicolor['petal_length']), '*')
plt.plot(iris_virginica["petal_length"], np.zeros_like(iris_virginica['petal_length']), '*')

plt.show()

# %% [markdown]
# # Histogram

# %%
# histogram of petal length
sns.FacetGrid(df, hue="species", height=5).map(sns.histplot, "petal_length").add_legend();
plt.show();

# %%
# histogram of petal width
sns.FacetGrid(df, hue="species", height=5).map(sns.histplot, "petal_width").add_legend();
plt.show();

# %%
# histogram of sepal lemgth
sns.FacetGrid(df, hue="species", height=5).map(sns.histplot, "sepal_length").add_legend();
plt.show();

# %%
# histogram of sepal width
sns.FacetGrid(df, hue="species", height=5).map(sns.histplot, "sepal_width").add_legend();
plt.show();

# %% [markdown]
# ## Observations:
#
#     Based on the histograms, we can see if we have to consider just a single feature then petal_length will be the best.
#     Petal_widht comes next, as it is seperating the 3 species quite well too

# %%
# sns.FacetGrid(df, hue="species", height=5).map(sns.histplot, "sepal_width", kde=True).add_legend();
# plt.show();

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
hist_grid = sns.FacetGrid(df, col='species')
hist_grid.map(sns.histplot, 'petal_length')

# %%
hist_grid = sns.FacetGrid(df, col='species')
hist_grid.map(sns.histplot, 'petal_width')

# %%
hist_grid = sns.FacetGrid(df, col='species')
hist_grid.map(sns.histplot, 'sepal_length')

# %%
hist_grid = sns.FacetGrid(df, col='species')
hist_grid.map(sns.histplot, 'sepal_width')

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(x=df.species, y=df.sepal_length)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
sns.boxplot(x=df.species, y=df.sepal_width)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_width'>

# %%
sns.boxplot(x=df.species, y=df.petal_length)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
sns.boxplot(x=df.species, y=df.petal_width)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %%
sns.scatterplot(data=df, x = "sepal_width", y = 'sepal_length')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>

# %%
sns.scatterplot(data=df, x = "petal_length", y = 'petal_width')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
df.isnull().values.any()
# Out:
# False

# %%
# print(df['sepal_length'].quantile(0.50)) 

# print(df['sepal_length'].quantile(0.95)) 

# df['sepal_length'] = np.where(df['sepal_length'] < 5.5, 5.8, df['sepal_length'])

# df.describe()

# %%
sns.boxplot(y=df.sepal_length)
# Out:
# <AxesSubplot:ylabel='sepal_length'>

# %%
sns.boxplot(y=df.sepal_width)
# Out:
# <AxesSubplot:ylabel='sepal_width'>

# %% [markdown]
# #### Outlier can be observed in sepal width

# %%
sns.boxplot(y=df.petal_length)
# Out:
# <AxesSubplot:ylabel='petal_length'>

# %%
sns.boxplot(y=df.petal_width)
# Out:
# <AxesSubplot:ylabel='petal_width'>

# %%
print(df['sepal_width'].quantile(0.50)) 

print(df['sepal_width'].quantile(0.95)) 

df['sepal_width'] = np.where(df['sepal_width'] > 4.0, 3.05, df['sepal_width'])
df['sepal_width'] = np.where(df['sepal_width'] < 2.3, 3.05, df['sepal_width'])

df.describe()
# Out:
# 3.0
# 3.8
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054333      3.758667     1.198667
# std        0.828066     0.370875      1.764420     0.763161
# min        4.300000     2.300000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.000000      6.900000     2.500000

# %%
sns.boxplot(y=df.sepal_width)
# Out:
# <AxesSubplot:ylabel='sepal_width'>

# %%
sns.pairplot(df, hue='species')

# %% [markdown]
# ## Final Observations:
#
# ### 1. The plot between petal.length and petal.width is comparatively better. While Setosa can be easily identified Versicolor and Virginica have some overlap.
# ### 2. Petal width of iris setosa is more, hence it is easy to identify iris-setosa using petal width
# ### 3.
